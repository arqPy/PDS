# %% [markdown]
# <a href="https://colab.research.google.com/github/arqPy/PDS/blob/main/PDS_LATHI_CAP3_EXERC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capítulo 3
# ## ANÁLISE NO DOMÍNIO DO TEMPO DE SISTEMAS EM TEMPO DISCRETO

# %% [markdown]
# ### 3.1 Tamanho de um Sinal em tempo discreto 225
#
# 3.1-1 Determine a energia dos sinais mostrados nas Figs. P3.1-1.
#
# ![](https://github.com/arqPy/PDS/blob/main/PDS/img/Figura%20P3.1-1.png?raw=true)
#
# 3.1-2 Determine a potência dos sinais mostrados nas Figs. P3.1-2
#
# ![](https://github.com/arqPy/PDS/blob/main/PDS/img/Figura%20P3.1-2.png?raw=true)
#
# 3.1-3 Mostre que a potência de um sinal De $D e^{j(2π/N_0)n}$ é $|D|^2$. Portanto,mostre que a potência de um sinal $x[n] = \sum_{r=0}^{N_o-1} e^{j(2π/N_0)n}$ e $P_x = |D_r|^2$
#
# ___________________________________
#
# ___________________________________
#
# ___________________________________
#
# ___________________________________
#
# ___________________________________
#
# ___________________________________

# %% [markdown]
# ### 3.2 Operações Úteis com Sinais 227
#
# 3.2-1 Se a energia de um sinal x[n] é $E_x$, então determine a energia dos seguintes sinais:
#
# (a) $x[-n]$
#
# (b) $x[n-m]$
#
# (c) $x[m-n]$
#
# (d) $Kx[n] \ (m \in Z \ K constante )$
#
# 3.2-2 Se a potência de um sinal periódico x[n] é Px, determine e comente a respeito das potências e valores rms dos seguintes sinais:
#
# (a) $-x[n]$
#
# (b) $x[-n]$
#
# (c) $x[n-m] \ (m \ inteiro)$
#
# (d) $cx[n]$
#
# (e) $x[m-n] \ (m \ inteiro)$
#
# 3.2-3 Para o sinal mostrado na Fig. P3.1-1b, trace os seguintes sinais:

# %% [markdown]
# ### 3.3 Alguns Modelos Úteis em Tempo Discreto
#
#
# ![](https://github.com/arqPy/PDS/blob/main/PDS/img/Item3.3.png?raw=true)

# %% [markdown]
# ### 3.4 Exemplos de Sistemas em Tempo Discreto 237
# _____________
#
# 3.4-1 A saída de uma caixa registradora y[n] representa o custo total de n itens registrados pelo caixa. A entrada x[n] é o custo do n-ésimo item.
#
# (a) Escreva a equação diferença relacionando y[n] com x[n].
#
# **Solução**
#
# $x[n] = y[n]-y[n-1]$
#
# $y[n] = x[n]+y[n-1]$
#
# (b) Realize este sistema usando um elemento
# de atraso de tempo.
#
# **Solução**
#
# ![](https://github.com/arqPy/PDS/blob/main/PDS/img/diagrama_EDLIT.png?raw=true)
# _________________________
#
# 3.4-2 Seja p[n] a população de um certo país no começo do n-ésimo ano. As taxas de nascimento e mortalidade da população durante qualquer ano são 3,3 e 1,3%, respectivamente. Se i[n] é o número total de imigrantes entrando no país durante o n-ésimo ano, escreva a equação diferença relacionando p[n + 1], p[n] e i[n]. Assuma que os imigrantes entram no país ao longo do ano em uma taxa uniforme.
#
# **Solução**
#
# $p[n+1] = p[n]+ \frac{3.3 - 1.3}{100}p[n] + i[n] + ?$
# _________________________
#
# 3.4-3 A média móvel é utilizada para detectar uma tendência de uma variável que varia rapidamente, tal como a média do mercado de ações. A variável pode flutuar (para cima ou para baixo) diariamente, mascarando sua tendência de longo prazo. Podemos perceber a tendência de longo prazo suavizando ou obtendo a média dos N valores passados da variável. Para o mercado de ações, podemos considerar uma média móvel y[n] de 5 dias, sendo a média dos 5 últimos dias dos valores de fechamento do mercado x[n], x[n − 1],..., x[n − 4].
#
# (a) Escreva a equação diferença relacionando y[n] com a entrada x[n].
#
# **Solução**
#
# $y[n] = x[n] + x[n -1] + x[n -2] + x[n -3] + x[n -4]$
#
# (b) Utilize elementos de atraso de tempo para implementar o filtro de média móvel de 5 dias.
#
# **Solução**
#
#
# ![](https://github.com/arqPy/PDS/blob/main/PDS/img/MediaMovel5.png?raw=true)
# _________________________

# %% [markdown]
# ### 3.5 Equações de Sistemas em Tempo Discreto 246
# 3.5-1 Resolva recursivamente (apenas os três primeiros termos) das equações:
# ________________
#
# (a) $y[n+1] -0,5y[n] = 0$, com $y[-1] = 10$
#
# *Reescrevendo a equação com um atraso*
#
# $y[n] = 0.5y[n-1]$
#
# para n = 0, $y[0] = 0.5y[-1] = 0.5x10 = 5$
#
# para n = 1, $y[1] = 0.5y[0] = 0.5x5 = 2.5$
#
# para n = 2, $y[2] = 0,5y[1] = 0.5x2,5 = 1.25$
#
#
# $y[n] = [10, \underline{5}, 2.5, 1.25, ...]$
#
# ________________
#
# (b) $y[n+1] + 2y[n] = x[n+1]$, com $x[n] = e^{-n}u[n] \  e \ y[-1] = 0$
#
# *Reescrevendo a equação com um atraso*
#
# $y[n] = x[n] -2y[n-1]$
#
# para n = 0, $y[0] = x[0] - 2y[-1] =  1 - 0= 1$
#
# para n = 1, $y[1] =  x[1] - 2y[0]=  e^{-1} - 1= -0.6321$
#
# para n = 2, $y[2] = x[2] - 2y[1]=  e^{-2} + 1.2642= 1.4$
#
#
# $y[n] = [0, \underline{1}, -0.632, 1.4, ...]$
#
# ________________
#
# 3.5- 2 Resolva as seguintes equações recursivamente (apenas os três primeiros termos):
#
# <center>
# $y[n] - 0.6y[n - 1] - 0.16y[n - 2] = 0,\ com \ y[-1]= -25, y[-2]=0$
# </center>
#
# **Solução**
#
#
# | n	| y[n-2]	| y[n-1]	| y[n] |
# | --- | ---: | ---: | ---: |
# | 0	| 0	| -25	| -15 |
# | 1	| -25| 	-15 |	-13 |
# | 2 |	-15 |	-13 |	-10,2 |
#
#
# 3.5-3 Resolva recursivamente a equação diferença de segunda ordem,$ y[n] =  x[n] - \frac{1}{4}y[n-1] - \frac{1}{16}y[n-2]
# $ , Eq. (3.10)
#
# para a estimativa de vendas (apenas os três primeiros termos), assumindo $y[−1] = y[−2] = 0$ e $x[n] = 100u[n]$.
#
# **Solução**
#
# | n	| x[n] | y[n-2]	| y[n-1]	| y[n] |
# | --- | ---: | ---: | ---: | ---: |
# | 0	| 100	| 0	|0	| 100 |
# | 1	| 100	| 0	| 100 |	75 |
# | 2	| 100	| 100 |	75 |	75 |

# %% [markdown]
# ### 3.6 Resposta do Sistema a Condições Internas
# ### Resposta de Entrada Nula 251
#
# (x[n] é irrelevante)
#
#
# EXEMPLO 3.10 Para um sistema LDIT descrito pela equação diferença
#
# <center>
# $y[n+2] - 0.6y[n + 1] - 0.16y[n] = 5x[n+2]$
# </center>
#
# determine a resposta total se as condições iniciais forem $y[−1] = 0$ e $y[−2] = \frac{25}{4}$ e se a entrada for $x[n] = 4^{−n}u[n]$. Neste exemplo, é determinado apenas a componente de entrada nula $y_0[n]$. A componente de estado nulo é determinada posteriormente, no Exemplo 3.14.
#
# **Solução**
#
# A equação do sistema na notação operacional é
# <center>
# $(E^2 - 0.6E - 0.16)y[n] = 5E^2x[n]$
# </center>
# O polinômio característico é
#
# $\gamma^2 - 0.6\gamma - 0.16$
#
# A equação característica é
#
# $\gamma^2 - 0.6\gamma - 0.16 = 0$
#
# $(\gamma + 0.2)(\gamma - 0.8) = 0$
#
# As raízes características são $\gamma_1 = -0.2$ e $\gamma_2 = 0.8$. A resposta de entrada nula é
# <center>
# $y[n] = c_1(-0.2)^n + c_2(0.8)^n$ Eq. 3.40
# </center>
#
# Para determinar as constantes arbitrárias $c_1$ e $c_2$, faz-se n = −1 e n = −2 na Eq. (3.40) substituindo
# para condições iniciais y[−1] = 0 e y[−2] = 25/4, obtendo assim:
#
# $c_1 = \frac{1}{5} \ e \  c_2 = \frac{4}{5}$
#
# Portanto,
#
# <center>
# $y[n] =  \frac{1}{5}(-0.2)^n +  \frac{4}{5}(0.8)^n$
# </center>
#
# O leitor pode verificar esta solução determinando os primeiros termos usando o método interativo (veja Exemplos 3.8 e 3.9)
#
# _____________________
#
# 3.6-1 Resolva
#
# <center>
# $y[n+2] + 3y[n + 1] + 2y[n] = 0$, considere que $y[-1]=0 \ e \ y[-2]=1$
# </center>
#
# **Solução**
#
# A equação do sistema na notação operacional é
# <center>
# $(E^2 + 3E +2)y[n] = 0$
# </center>
#
# A equação característica é
#
# $\gamma^2 +3\gamma +2 = 0$
#
# $(\gamma + 1)(\gamma + 2) = 0$
#
# A resposta de entrada nula é
# <center>
# $y[n] = c_1(-1)^n + c_2(-2)^n$
# </center>
#
# Resolvendo o sistema com as condições iniciais dadas, obtem-se:
#
# $c_1 = 2 \ e \  c_2 = -4$
#
# Portanto,
#
# <center>
# $y[n] =  2(-1)^n - 4(-2)^n \ para \ n \geq 0$
# </center>
#
# _____________________
#
#
# 3.6-2 Resolva
#
# <center>
# $y[n+2] + 2y[n + 1] + y[n] = 0$, considere que $y[-1]=1 \ e \ y[-2]=1$
# </center>
#
# **Solução**
#
# A equação do sistema na notação operacional é
# <center>
# $(E^2 + 2E +1)y[n] = 0$
# </center>
#
# A equação característica é
#
# $\gamma^2 +2\gamma +1 = 0$
#
# $(\gamma + 1)^2 = 0$, raízes reais iguais
#
# A resposta de entrada nula é
# <center>
# $y[n] = c_1(-1)^n + c_2n(-1)^n$
# </center>
#
# _____________________
#
#
# 3.6-7 Considere o sistema em tempo discreto y[n] + y[n −1] + 0,25y[n − 2] = x[n − 8]. Determine a resposta de entrada nula $y_0[n]$ se $y_0[−1] = 1 \ e \ y_0[1] = 1$.
#
# A equação do sistema na notação operacional, após o avanço de 2, é
# <center>
# $(E^2 + E +0.25)y[n] = 0$, resposta a entrada nula
# </center>
#
# A equação característica é
#
# $\gamma^2 + \gamma + 0.25 = 0$
#
# $(\gamma + \frac{1}{2})^2 = 0$, raízes reais iguais
#
# A resposta de entrada nula é
# <center>
# $y[n] = c_1(-0.5)^n + c_2n(-0.5)^n$
# </center>
#
# Equacionando o sistema de acordo com as condições iniciais dadas:
#
# $\begin{array}{ll}-2c_1 + 2c_2 = 1\\-0.5c_1 - 0.5c_2 = 1\end{array}$
#
# Resolvendo o sistema , obtem-se:
#
# $c_1 = -1.25 \ e \  c_2 = -0.75$
#
# Portanto,
#
# <center>
# $y[n] =  -1.25(-0.5)^n - 0.75n(-0.5)^n \ para \ n \geq 0$
# </center>

# %% [markdown]
# ### 3.7 Resposta h[n] ao Impulso Unitário 256
#
# $Q[E]h[n] = P[E]\delta[n] $, **Eq. (3.43)**
#
# A resposta h[n] ao impulso é a solução da  equação para a entrada δ[n] como todas as condições iniciais nulas, ou seja, $h[n<0] = 0$
#
#  h[n] é a resposta do sistema para a entrada δ[n], a qual é zero para n > 0. Sabendo que quando a entrada é zero, apenas os modos característicos podem ser mantidos pelo sistema. Portanto, h[n] deve ser constituído pelos modos característicos do sistema para n > 0. Para n = 0, ele pode ter algum valor não nulo $A_0$, de tal forma que a equação geral de h[n] pode ser descrita por
#
#  $h[n] = A_0\delta[n]+y_c[n]u[n]$, **Eq. (3.47)**
#
# na qual $y_c[n]$ é a combinação linear dos modos característicos. Substituindo agora a Eq. (3.47) na Eq. (3.43) no lugar de Q[n]
#
# $Q[E](A_0δ[n] + y_c[n]u[n]) = P[E]δ[n]$ como $Q[E]y_c[n]u[n] = 0$
#
# obtem-se $A_0Q[E]δ[n] = P[E]δ[n]$, ou seja,
#
# $A_0(\delta[n+N]+a_1\delta[n+N-1]+...+ a_N\delta[n])=b_0\delta[n]+b_1\delta[n+N-1] + ...+b_N\delta[n]$
#
# Fazendo n = 0 nesta equação e usando o fato de que δ[m] = 0 para todo m ≠ 0 e δ[0] = 1, obtem-se
#
# $A_0(0+0+...+a_N) = b_N$
#
# $A_0a_N = b_N \ \Rightarrow \ A_0=\frac{b_N}{a_N}$
#
#
# EXEMPLO 3.11 Determine h[n], a resposta ao impulso unitário de um sistema descrito pela equação
#
# $y[n] - 0.6y[n - 1] - 0.16y[n - 2] = 5x[n]$
#
# **Solução**
#
# Para determinar a resposta ao impulso unitário, vamos considerar a entrada x[n] = δ[n] e a saída y[n] = h[n] na Eq. (3.45), obtendo
#
# $h[n] - 0.6h[n - 1] - 0.16h[n - 2] = 5\delta[n]$ Eq. 3.46
#
# sujeita ao estado inicial nulo, ou seja, h[−1] = h[−2] = 0 (Sistema Causal h[n] = 0 para n < 0 ). Fazendo n = 0 nesta equação,
#
# $h[0] - 0.6h[- 1] - 0.16h[-2] = 5\delta[0] $
#
# $h[0] = 5$
#
# A seguir, fazendo n = 1 na Eq. (3.46) e usando h[0] = 5,
#
# $h[1] - 0.6h[0] - 0.16h[-1] = 5\delta[1] $
#
# $h[1] - 3 - 0 = 0 \Rightarrow h[1[ = 3$
#
# ...
#
# EXEMPLO 3.12 Determine a resposta **h[n]** ao impulso para o sistema do Exemplo 3.11
#
# **Resposta**
#
# Esta equação pode ser expressa na forma operador avanço por
#
# $y[n + 2] - 0.6y[n + 1] - 0.16y[n] = 5x[n + 2]$
#
# A equação do sistema na notação operacional é
# <center>
# $(E^2 - 0.6E - 0.16)y[n] = 5E^2x[n]$
# </center>
# O polinômio característico é
#
# $\gamma^2 - 0.6\gamma - 0.16$
#
# A equação característica é
#
# $\gamma^2 - 0.6\gamma - 0.16 = 0$
#
# $(\gamma + 0.2)(\gamma - 0.8) = 0$
#
# As raízes características são $\gamma_1 = -0.2$ e $\gamma_2 = 0.8$. A resposta de entrada nula é
# <center>
# $y[n] = c_1(-0.2)^n + c_2(0.8)^n$ Eq. 3.40
# </center>
#
# _____________________
#
#
# 3.7-1 Determine a resposta **h[n]** ao impulso para os sistemas especificados pelas seguintes equações:
#
# a) $y[n+1] + 2y[n]  = x[n]$
#
# **Solução:**
#
# $h[n+1] + 2h[n]  = \delta[n]$, **Eq. 1**
#
# Onde, 2 é o coeficiente da saída h[n] e 1 é o coeficiente da entrada $\delta[n]$, quando n = 0
#
# Assim, $A_0= \frac{1}{2}$
#
# $h[n] = \frac{1}{2}\delta[n]+y_c[n]u[n]$
#
# Resolvendo $y_c[n]$, autovalores:
#
# $E + 2 = 0 \Rightarrow E = -2$
#
# $h[n] = \frac{1}{2}\delta[n]+c(-2)^nu[n]$ **Eq. 2**
#
# Para determinar o valor da constante, faz-se o uso das condições iniciai, h[n<0]=0 na Eq. 1. Por exemplo para n=-1, tem-se:
#
#
# $h[0] + 2h[-1]  = \delta[-1] \Rightarrow h[0] + 2x0 = 0 \Rightarrow h[0] = 0 $, substituindo na Eq. 2
#
#
# $h[0] = \frac{1}{2}\delta[0]+c(-2)^0u[0]$
#
# $0 = \frac{1}{2}.1+c1.1 \Rightarrow c = -\frac{1}{2}$
#
# Finalmente,
#
#
# $h[n] = \frac{1}{2}\delta[n]- \frac{1}{2}(-2)^nu[n]$
#
#
#
# b) $y[n] + 2y[n - 1]  = x[n]$
#
#
# _____________________
#
# 3.7-2 Repita o Prob. 3.7-1 para
# $(E^2 - 6E + 9)y[n] = Ex[n]$
#
#
# _____________________
#
#
# 3.7-3 Repita o Prob. 3.7-1 para $y[n] - 6y[n - 1] + 25y[n-2] = 2x[n[ - 4x[n-1]$

# %%
c2 = -3/4
c1 = -5/4
c1
# Out:
# -1.25

# %%
import numpy as np

# %%
2*0.6321
# Out:
# 1.2642
